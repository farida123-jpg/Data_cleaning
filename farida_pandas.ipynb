# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #pandas series

# %%
data = pd.Series([1.2,3,3,6])
data
# Out:
# 0    1.2
# 1    3.0
# 2    3.0
# 3    6.0
# dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#explicit indexing
data_explict = pd.Series([1.2,3,4,5], index = ['a','b','c','d'])

# %%
data_explict.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
#values attribute
data.values
# Out:
# array([1.2, 3. , 3. , 6. ])

# %%
data
# Out:
# 0    1.2
# 1    3.0
# 2    3.0
# 3    6.0
# dtype: float64

# %%
data[0]#first item in the series
# Out:
# np.float64(1.2)

# %%
#first 3 elements
data[0:3]
# Out:
# 0    1.2
# 1    3.0
# 2    3.0
# dtype: float64
